# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("..", "..")))  # para importar modules do projeto

from testes.teste_grande_volume import testar_desempenho
from view.plots.plot_definicoes import plot_sucesso_falhas

# %%
quantidades = [10, 50, 100, 200]
sucessos_total = []
falhas_total = []

for qtd in quantidades:
    sucesso, erro = testar_desempenho(qtd)
    sucessos_total.append(sucesso)
    falhas_total.append(erro)
# Out:
# 📝 Roteirização concluída para 10 entregas.
# ⏱️ Tempo de execução: 0.0014 segundos
# 💾 Uso de memória atual: 2.55 KB
# 📈 Pico de memória: 3.70 KB
# ✅ Entregas com sucesso: 10 | (100.00%)
# ❌ Entregas com erro: 0 | (0.00%
#
#
# 📝 Roteirização concluída para 50 entregas.
# ⏱️ Tempo de execução: 0.0064 segundos
# 💾 Uso de memória atual: 11.23 KB
# 📈 Pico de memória: 12.38 KB
# ✅ Entregas com sucesso: 50 | (100.00%)
# ❌ Entregas com erro: 0 | (0.00%
#
#
# 📝 Roteirização concluída para 100 entregas.
# ⏱️ Tempo de execução: 0.0136 segundos
# 💾 Uso de memória atual: 20.76 KB
# 📈 Pico de memória: 21.84 KB
# ✅ Entregas com sucesso: 100 | (100.00%)
# ❌ Entregas com erro: 0 | (0.00%
#
#
# 📝 Roteirização concluída para 200 entregas.
# ⏱️ Tempo de execução: 0.0260 segundos
# 💾 Uso de memória atual: 44.57 KB
# 📈 Pico de memória: 45.68 KB
# ✅ Entregas com sucesso: 147 | (73.50%)
# ❌ Entregas com erro: 53 | (26.50%

# %%
plot_sucesso_falhas(quantidades, sucessos_total, falhas_total)
