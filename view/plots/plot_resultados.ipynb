# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("..", "..")))  # para importar modules do projeto

RAIZ_PROJETO = os.path.abspath(os.path.join(os.path.dirname(__file__) if '__file__' in locals() else os.getcwd(), '..', '..'))
if RAIZ_PROJETO not in sys.path:
    sys.path.append(RAIZ_PROJETO)

from testes.comparador_testes import comparar_algoritmos_estruturas
from view.plots.plot_definicoes import plot_comparativo_desempenho

# %%
def main():
    print("Iniciando a execução dos testes para geração de gráficos...")
    # 1. Executar os testes para obter os dados brutos
    # A função comparar_algoritmos_estruturas já imprime a tabela,
    # e agora também retorna os dados brutos.
    resultados_brutos = comparar_algoritmos_estruturas()

    if not resultados_brutos:
        print("Nenhum resultado foi retornado pelos testes. Gráficos não serão gerados.")
        return

    # Preparar diretório de saída para os gráficos
    base_path_para_plots = os.path.dirname(__file__) if '__file__' in locals() else os.getcwd()
    output_dir = os.path.join(base_path_para_plots, "imagens_graficos")
    os.makedirs(output_dir, exist_ok=True)
    print(f"Gráficos serão salvos em: {output_dir}")

    # 2. Gerar e salvar o gráfico de Tempo de Execução
    plot_comparativo_desempenho(
        resultados_brutos=resultados_brutos,
        metrica="tempo", # Chave do dicionário de resultados
        titulo="Comparativo de Tempo de Execução por Estrutura de Grafo",
        ylabel="Tempo Médio de Execução (s)",
        nome_arquivo_saida=os.path.join(output_dir, "comparativo_tempo_execucao.png")
    )

    # 3. Gerar e salvar o gráfico de Uso de Memória
    plot_comparativo_desempenho(
        resultados_brutos=resultados_brutos,
        metrica="memoria_pico_kb", # Chave do dicionário de resultados
        titulo="Comparativo de Pico de Memória por Estrutura de Grafo",
        ylabel="Pico de Memória Utilizada (KB)",
        nome_arquivo_saida=os.path.join(output_dir, "comparativo_memoria_pico.png")
    )

    print("Geração de gráficos concluída.")

if __name__ == "__main__":
    main()
# Out:
# Iniciando a execução dos testes para geração de gráficos...
# 🔍 Comparando desempenho dos algoritmos de roteirização:
#
# --- CENÁRIO: 10 Entregas, 50 Caminhões por Centro de Distribuição ---
#
#   Testando Estrutura: Lista de Adjacência (Heap)...
#     Tempo: 1.2260s, Memória Pico: 15.85KB
#
#   Testando Estrutura: Lista de Adjacência (Lista Simples)...
#     Tempo: 1.7037s, Memória Pico: 13.62KB
#
#   Testando Estrutura: Matriz de Adjacência (Heap)...
#     Tempo: 4.8613s, Memória Pico: 12.48KB
#
#   Testando Estrutura: Matriz de Adjacência (Lista Simples)...
#     Tempo: 3.5324s, Memória Pico: 12.90KB
#
#   Testando Estrutura: Lista de Arestas (Heap)...
#     Tempo: 1.7381s, Memória Pico: 9.68KB
#
#   Testando Estrutura: Lista de Arestas (Lista Simples)...
#     Tempo: 2.4341s, Memória Pico: 13.69KB
#
#   Testando Estrutura: Dicionário de Dicionários (Heap)...
#     Tempo: 1.3162s, Memória Pico: 13.96KB
#
#   Testando Estrutura: Dicionário de Dicionários (Lista Simples)...
#     Tempo: 2.5907s, Memória Pico: 14.50KB
#
#   Testando Estrutura: Grafo com Objetos (Heap)...
#     Tempo: 1.5328s, Memória Pico: 11.80KB
#
#   Testando Estrutura: Grafo com Objetos (Lista Simples)...
#     Tempo: 2.8018s, Memória Pico: 13.85KB
#
#   Testando Estrutura: NetworkX (Nativo/Heap)...
#     Tempo: 0.7964s, Memória Pico: 57.46KB
#
# --- CENÁRIO: 50 Entregas, 50 Caminhões por Centro de Distribuição ---
#
#   Testando Estrutura: Lista de Adjacência (Heap)...
#     Tempo: 6.6735s, Memória Pico: 21.03KB
#
#   Testando Estrutura: Lista de Adjacência (Lista Simples)...
#     Tempo: 19.7667s, Memória Pico: 23.26KB
#
#   Testando Estrutura: Matriz de Adjacência (Heap)...
#     Tempo: 43.4975s, Memória Pico: 22.27KB
#
#   Testando Estrutura: Matriz de Adjacência (Lista Simples)...
#     Tempo: 36.4867s, Memória Pico: 21.76KB
#
#   Testando Estrutura: Lista de Arestas (Heap)...
#     Tempo: 17.1248s, Memória Pico: 18.20KB
#
#   Testando Estrutura: Lista de Arestas (Lista Simples)...
#     Tempo: 20.5092s, Memória Pico: 23.26KB
#
#   Testando Estrutura: Dicionário de Dicionários (Heap)...
#     Tempo: 12.4567s, Memória Pico: 21.35KB
#
#   Testando Estrutura: Dicionário de Dicionários (Lista Simples)...
#     Tempo: 24.0397s, Memória Pico: 24.00KB
#
#   Testando Estrutura: Grafo com Objetos (Heap)...
#     Tempo: 15.3326s, Memória Pico: 21.50KB
#
#   Testando Estrutura: Grafo com Objetos (Lista Simples)...
#     Tempo: 26.4793s, Memória Pico: 23.70KB
#
#   Testando Estrutura: NetworkX (Nativo/Heap)...
#     Tempo: 8.2259s, Memória Pico: 23.57KB
#
#
# 📊 Resultados Comparativos Consolidados:
# ╒═══════════════════════════════════════════╤═══════════════╤═════════════╤═════════════════════╤════════════╤═════════╕
# │ Estrutura                                 │   Nº Entregas │   Tempo (s) │   Memória Pico (KB) │   Sucessos │   Erros │
# ╞═══════════════════════════════════════════╪═══════════════╪═════════════╪═════════════════════╪════════════╪═════════╡
# │ Lista de Adjacência (Heap)                │            10 │      1.226  │               15.85 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Adjacência (Lista Simples)       │            10 │      1.7037 │               13.62 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Matriz de Adjacência (Heap)               │            10 │      4.8613 │               12.48 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Matriz de Adjacência (Lista Simples)      │            10 │      3.5324 │               12.9  │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Arestas (Heap)                   │            10 │      1.7381 │                9.68 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Arestas (Lista Simples)          │            10 │      2.4341 │               13.69 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Dicionário de Dicionários (Heap)          │            10 │      1.3162 │               13.96 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Dicionário de Dicionários (Lista Simples) │            10 │      2.5907 │               14.5  │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Grafo com Objetos (Heap)                  │            10 │      1.5328 │               11.8  │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Grafo com Objetos (Lista Simples)         │            10 │      2.8018 │               13.85 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ NetworkX (Nativo/Heap)                    │            10 │      0.7964 │               57.46 │          7 │       3 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Adjacência (Heap)                │            50 │      6.6735 │               21.03 │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Adjacência (Lista Simples)       │            50 │     19.7667 │               23.26 │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Matriz de Adjacência (Heap)               │            50 │     43.4975 │               22.27 │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Matriz de Adjacência (Lista Simples)      │            50 │     36.4867 │               21.76 │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Arestas (Heap)                   │            50 │     17.1248 │               18.2  │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Lista de Arestas (Lista Simples)          │            50 │     20.5092 │               23.26 │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Dicionário de Dicionários (Heap)          │            50 │     12.4567 │               21.35 │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Dicionário de Dicionários (Lista Simples) │            50 │     24.0397 │               24    │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Grafo com Objetos (Heap)                  │            50 │     15.3326 │               21.5  │         33 │      17 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ Grafo com Objetos (Lista Simples)         │            50 │     26.4793 │               23.7  │         34 │      16 │
# ├───────────────────────────────────────────┼───────────────┼─────────────┼─────────────────────┼────────────┼─────────┤
# │ NetworkX (Nativo/Heap)                    │            50 │      8.2259 │               23.57 │         32 │      18 │
# ╘═══════════════════════════════════════════╧═══════════════╧═════════════╧═════════════════════╧════════════╧═════════╛
# Gráficos serão salvos em: c:\Users\Anderson Correia\Documents\GitHub\2005LucasLongo\A3-Estruturas-de-dados-e-analise-de-algoritmos\view\plots\imagens_graficos
# DEBUG: Metrica 'tempo', Max valor barra: 43.50, Novo YLim superior: 58.72
# DEBUG: YLim após set_ylim: (np.float64(0.0), np.float64(58.72163377499492))
# DEBUG: YLim ANTES de savefig (após tight_layout se ativo): (np.float64(0.0), np.float64(58.72163377499492))
# Gráfico salvo em: c:\Users\Anderson Correia\Documents\GitHub\2005LucasLongo\A3-Estruturas-de-dados-e-analise-de-algoritmos\view\plots\imagens_graficos\comparativo_tempo_execucao.png
# DEBUG: YLim APÓS savefig: (np.float64(0.0), np.float64(58.72163377499492))
# DEBUG: Metrica 'memoria_pico_kb', Max valor barra: 57.46, Novo YLim superior: 71.83
# DEBUG: YLim após set_ylim: (np.float64(0.0), np.float64(71.829833984375))
# DEBUG: YLim ANTES de savefig (após tight_layout se ativo): (np.float64(0.0), np.float64(71.829833984375))
# Gráfico salvo em: c:\Users\Anderson Correia\Documents\GitHub\2005LucasLongo\A3-Estruturas-de-dados-e-analise-de-algoritmos\view\plots\imagens_graficos\comparativo_memoria_pico.png
# DEBUG: YLim APÓS savefig: (np.float64(0.0), np.float64(71.829833984375))
# Geração de gráficos concluída.
